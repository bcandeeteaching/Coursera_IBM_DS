# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will summarize Data Science Tools and Ecosystems

# %% [markdown]
# **Objectives**
# - List popular languages used in data science
# - List commonly used libraries for data science
# - List some open source data science tools
# - Demonstrate evaluating arithmetic in Python

# %% [markdown]
# Some popular languages data scientists use are:
# 1. Python
# 2. R
# 3. Julia

# %% [markdown]
# Some of the commonly used libraries for data science are:
# 1. scikit-learn for machine learning in python
# 2. matplotlib for data visualization in python
# 3. numpy for data analysis in python

# %% [markdown]
# | Data Science Tools |
# |:-|
# | KNIME |
# | R Studio |
# | JupyterLab |

# %% [markdown]
# ### Below are some examples of evaluating arithmetic expressions in Python

# %%
# This cell demonstrates multiplying and adding integers
(3 * 4) + 5
# Out:
# 17

# %%
# This cell converts 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Ben Candee
